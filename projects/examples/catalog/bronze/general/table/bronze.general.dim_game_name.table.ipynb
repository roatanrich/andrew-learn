# %% [markdown]
# # bronze.general.dim_game_name.table
#
# ## Overview
#
# |Attribute|Details|
# ---|---|
# |Created By|Andrew Ryan|
# |Notebook Type|table|
# |Workflow Parent||
# |Target Catalog|bronze|
# |Target Database|general|
#
# ## Purpose
#
# This notebook creates the bronze.general.dim_game_name table.
#
# ## Revisions
#
# |Revision Date|Developer|Comment|
# ---|---|---|
# |2025-06-30|Andrew Ryan|Created|

# %% [markdown]
# # Setting the environment.
# environment = dbutils.secrets.get(scope = "workspace-details", key = "name")
# spark.conf.set("sql.environment", environment)
#
# # Setting the table names.
# table_name = "bet_config"
# stage_table_name = f"{environment}_silver.staging.{table_name}"
# spark.conf.set("sql.table_name", table_name)
# spark.conf.set("sql.stage_table_name", stage_table_name)

# %%
# %sql
DROP TABLE IF EXISTS dim_game_name;

# %%
# %sql
CREATE TABLE IF NOT EXISTS dim_game_name (
    dim_game_name_id BIGINT NOT NULL GENERATED BY DEFAULT AS IDENTITY(START WITH 1 INCREMENT BY 1) COMMENT "Internal identifier for the row of data in the table.",
    game_name STRING COMMENT 'Name of the game',
    CONSTRAINT pk_bronze_general_dim_game_name_dim_game_name_id PRIMARY KEY (dim_game_name_id)
) COMMENT 'Game name lookup table'
