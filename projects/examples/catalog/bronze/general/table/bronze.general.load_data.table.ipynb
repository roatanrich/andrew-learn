# %% [markdown]
# # bronze.general.load_data.table
#
# ## Overview
#
# |Attribute|Details|
# ---|---|
# |Created By|Rich Henry|
# |Notebook Type|table|
# |Workflow Parent||
# |Target Catalog|bronze|
# |Target Database|general|
#
# ## Purpose
#
# This notebook create the bronze.general.<project name> table.
#
# ## Revisions
#
# |Revision Date|Developer|Comment|
# ---|---|---|
# |2025-06-19|Rich Henry|Created|

# %%
# %python

# Setting the environment.
environment = dbutils.secrets.get(scope = "workspace-details", key = "name")
spark.conf.set("sql.environment", environment)

# Setting the table names.
table_name = "bet_config"
stage_table_name = f"{environment}_silver.staging.{table_name}"
spark.conf.set("sql.table_name", table_name)
spark.conf.set("sql.stage_table_name", stage_table_name)

# %%
# %sql
DROP TABLE IF EXISTS project_name;

# %%
# %sql
CREATE TABLE IF NOT EXISTS project_name (
    project_name_id BIGINT NOT NULL GENERATED BY DEFAULT AS IDENTITY(START WITH 1 INCREMENT BY 1) COMMENT "Internal identifier for the row of data in the table.",
    project_name_name STRING COMMENT 'xxxxxxxxxxxxxxxxxxxxxxxxx',
    project_name_year INTEGER COMMENT 'xxxxxxxxxxxxxxxxxxxxxxxxx',
    CONSTRAINT pk_bronze_general.project_name.project_name_id PRIMARY KEY (project_name_id)
) COMMENT 'xxxxxxxxxxxxxxxxxxxxxxxxx'
